# %% [markdown]
# # Generative AI - SEBx & Combient Hackathon December 2023

# %% [markdown]
# - Upload the deployment key sent in email to your colab account.
# - Locate the deployment key in your colab disk. It will probably be in /
# - create the directory /root/.ssh
# - copy the key there and change permissions to the key
# - run the code to clone the repo below

# %%
# Assume that the deployment key is uploaded to /root/id_rsa
# !mkdir -p /root/.ssh # reate the directory /root/.ssh
# !mv /id_rsa /root/.ssh/id_rsa # copy the key there (assumes it was originally at /id_rsa
# !chmod a-r /root/.ssh/id_rsa # change permissions

# %%
# !ssh git@github.com -o StrictHostKeyChecking=accept-new
# !git clone ssh://git@github.com/banque-nouveau/bootcamp_dec7
